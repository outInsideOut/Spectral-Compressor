# %%
import librosa
import audio_io

audio_dict = audio_io.load_list(["thunder.wav", "kicks.wav")
# Out:
# done!

# %%
import numpy as np

np_thunder = thunder[0]
type(np_thunder)
np_thunder
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
import plotting

spectogram = plotting.calc_spectogram(audio[0])
plotting.plot_spectogram(spectogram, "Thunder")
